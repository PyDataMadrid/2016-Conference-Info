# %% [markdown]
# Nuevamente, vamos a leer primero unos datos...

# %%
# primero hacemos los imports de turno
import os
import datetime as dt

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline

# %% [markdown]
# # Lectura de un fichero de datos

# %%
# Leemos los datos del fichero 'mast.txt'
ipath = os.path.join('Datos', 'mast.txt')

def dateparse(date, time):
    YY = 2000 + int(date[:2])
    MM = int(date[2:4])
    DD = int(date[4:])
    hh = int(time[:2])
    mm = int(time[2:])
    
    return dt.datetime(YY, MM, DD, hh, mm, 0)
    

cols = ['Date', 'time', 'wspd', 'wspd_max', 'wdir',
        'x1', 'x2', 'x3', 'x4', 'x5', 
        'wspd_std']
wind = pd.read_csv(ipath, sep = "\s*", names = cols, 
                   parse_dates = {'Timestamp': [0, 1]}, index_col = 0,
                   date_parser = dateparse)
# Out:
# d:\users\X003621\AppData\Local\Continuum\Miniconda3\lib\site-packages\pandas\io\parsers.py:648: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %% [markdown]
# # Lectura de un segundo fichero de datos

# %%
# Leemos los datos del fichero 'model.txt'
ipath = os.path.join('Datos', 'model.txt')

model = pd.read_csv(ipath, sep = "\s*", skiprows = 3,
                    parse_dates = {'Timestamp': [0, 1]}, index_col = 'Timestamp')
# Out:
# d:\users\X003621\AppData\Local\Continuum\Miniconda3\lib\site-packages\pandas\io\parsers.py:648: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %%
for c in ['x1','x2','x3','x4','x5']: # Eliminamos unas columnas innecesarias
    _ = wind.pop(c)
wind.head(3)
# Out:
#                      wspd  wspd_max   wdir  wspd_std
# Timestamp
# 2013-09-04 00:00:00  2.21      2.58  113.5      0.11
# 2013-09-04 00:10:00  1.69      2.31   99.9      0.35
# 2013-09-04 00:20:00  1.28      1.50   96.0      0.08

# %%
model.head(3)
# Out:
#                      M(m/s)  D(deg)  T(C)  De(k/m3)  PRE(hPa)  RiNumber  RH(%)
# Timestamp
# 1984-01-01 00:00:00    20.8     243   7.3      1.25    1002.8      0.04   86.3
# 1984-01-01 01:00:00    20.8     243   7.3      1.25    1002.2      0.04   86.9
# 1984-01-01 02:00:00    20.6     243   7.4      1.24    1001.8      0.04   87.0

# %%
wind['Timestamp'] = wind.index
print(wind['Timestamp'].diff().min())
del wind['Timestamp']
# Out:
# 0 days 00:10:00

# %%
model['Timestamp'] = model.index
print(model['Timestamp'].diff().min())
del model['Timestamp']
# Out:
# 0 days 01:00:00

# %% [markdown]
# Tenemos datos con una frecuencia temporal mínima de 10 minutos (`wind`) frente a unos segundos datos con una frecuencia temporal de 1 hora (`model`).

# %% [markdown]
# # Inciso: `axis` 101

# %% [markdown]
# En muchas ocasiones vamos a encontrar una *keyword* llamada `axis`. Veamos en un momento cómo funciona en pandas para evitarnos posibles problemas e incongruencias:
#
# ## Posibilidades
#
# * axis = 0 (actúa sobre las filas/*rows*)
# * axis = 1 (actúa sobre las columnas/*columns*)
# * <span style="color:#888">axis = 2 (solo para `Panel`)</span>
#
# ![](imgs/DF_Rows_Columns.jpg)
# (fuente: http://stackoverflow.com/a/25774395/5216568).
#
# <br>
# <div class="alert alert-info">
# <p><b>Regla nemotécnica:</b></p>
# <p>Puedes pensar que el '1' es como una columna.</p>
# <p><b>Otras opciones:</b></p>
# <p>Otra opción sería usar `axis = 'index'` (similar a `axis = 0`) o `axis = 'columns'` (similar a `axis = 1`) para `DataFrame`s. Para `Panel`es tendríamos `items`, `minor`, `major` (similar a las opciones 0, 1 o 2).</p>.
# <p>Para `DataFrame`s también podéis usar `index = 'rows'`, que me parece que es más evidente que `'index'` pero no lo recomiendo ya que no está documentado en ningún sitio.</p>
# <p>Además, usar `'index'`, `'rows'`, `'columns'`,..., puede llegar a ser confuso ya que en muchos sitios nos encontraremos con *keywords* que usan esa nomenclatura.</p>.
# </div>
#
# Pero, que significa que 'actúa sobre las filas/columnas'. Veamos algunos ejemplo simples para ver si nos queda un poco más claro:

# %%
df = pd.DataFrame(np.array([[1, 10], [2, 20], [3,30]]), columns = ['A', 'B'])
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %% [markdown]
# Si no indicamos nada, por defecto, las operaciones se realizan sobre las filas (`axis = 0`), es decir, se cogen todos los elementos de fila de cada columna:

# %%
df.sum()
# Out:
# A     6
# B    60
# dtype: int64

# %%
# Lo anterior sería similar a 
df.sum(axis = 0)
# Out:
# A     6
# B    60
# dtype: int64

# %% [markdown]
# Si queremos que nos dé el resultado de cada fila, es decir, se cogen todos los elementos de columna de una fila, debemos indicar que `axis = 1`:

# %%
df.sum(axis = 1)
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %% [markdown]
# Otro ejemplo:

# %%
df < 10
# Out:
#       A      B
# 0  True  False
# 1  True  False
# 2  True  False

# %%
(df < 10).all()
# Out:
# A     True
# B    False
# dtype: bool

# %%
(df < 10).all(axis = 'columns') # en lugar de axis = 1 usamos axis = 'columns'
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
# Probad operaciones sobre df usando axis = 0, 1, 'index', rows', columns'

# %% [markdown]
# Espero que haya quedado un poco claro con estos ejemplos simples.

# %% [markdown]
# # Uniendo estructuras de datos pandas
#
# Lo que [vamos a ver no es evidente](http://pandas.pydata.org/pandas-docs/stable/merging.html) y, en algunos casos, es conveniente conocer [algebral relacional](https://en.wikipedia.org/wiki/Relational_algebra) para poder enterder qué es lo que está pasando.
#
# ## Uniendo datos usando `concat`

# %%
new = pd.concat([wind, model], axis = 0, join = 'outer')

# %%
new.head(5)
# Out:
#                      D(deg)  De(k/m3)  M(m/s)  PRE(hPa)  RH(%)  RiNumber  \
# Timestamp
# 2013-09-04 00:00:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 00:10:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 00:20:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 00:30:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 00:40:00     NaN       NaN     NaN       NaN    NaN       NaN
#
#                      T(C)   wdir  wspd  wspd_max  wspd_std
# Timestamp
# 2013-09-04 00:00:00   NaN  113.5  2.21      2.58      0.11
# 2013-09-04 00:10:00   NaN   99.9  1.69      2.31      0.35
# 2013-09-04 00:20:00   NaN   96.0  1.28      1.50      0.08
# 2013-09-04 00:30:00   NaN   99.2  1.94      2.39      0.26
# 2013-09-04 00:40:00   NaN  108.4  2.17      2.67      0.23

# %%
new.tail(5)
# Out:
#                      D(deg)  De(k/m3)  M(m/s)  PRE(hPa)  RH(%)  RiNumber  \
# Timestamp
# 2015-09-10 19:00:00      85      1.22     9.2    1008.5   67.9      0.25
# 2015-09-10 20:00:00      85      1.21     9.2    1008.3   68.0      0.28
# 2015-09-10 21:00:00      87      1.21     9.5    1008.1   69.1      0.24
# 2015-09-10 22:00:00      90      1.21    10.0    1008.0   72.3      0.10
# 2015-09-10 23:00:00      94      1.22    10.0    1007.9   73.9     -0.06
#
#                      T(C)  wdir  wspd  wspd_max  wspd_std
# Timestamp
# 2015-09-10 19:00:00  16.1   NaN   NaN       NaN       NaN
# 2015-09-10 20:00:00  16.2   NaN   NaN       NaN       NaN
# 2015-09-10 21:00:00  16.2   NaN   NaN       NaN       NaN
# 2015-09-10 22:00:00  16.0   NaN   NaN       NaN       NaN
# 2015-09-10 23:00:00  15.8   NaN   NaN       NaN       NaN

# %%
new.loc['2014/01/01 00:00':'2014/01/01 02:00']
# Out:
#                      D(deg)  De(k/m3)  M(m/s)  PRE(hPa)  RH(%)  RiNumber  \
# Timestamp
# 2014-01-01 00:00:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 00:10:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 00:20:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 00:30:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 00:40:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 00:50:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 01:00:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 01:10:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 01:20:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 01:30:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 01:40:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 01:50:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 02:00:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2014-01-01 00:00:00     206      1.23    12.7     992.4   90.9      0.03
# 2014-01-01 01:00:00     206      1.23    12.7     992.4   89.2      0.03
# 2014-01-01 02:00:00     202      1.23    13.1     992.3   87.8      0.02
#
#                      T(C)   wdir   wspd  wspd_max  wspd_std
# Timestamp
# 2014-01-01 00:00:00   NaN  224.6  12.15     13.95      0.60
# 2014-01-01 00:10:00   NaN  224.5  11.83     13.21      0.63
# 2014-01-01 00:20:00   NaN  225.3  11.05     13.43      0.67
# 2014-01-01 00:30:00   NaN  219.9  11.84     13.59      0.60
# 2014-01-01 00:40:00   NaN  218.9  12.99     15.43      0.89
# 2014-01-01 00:50:00   NaN  219.6  12.89     16.02      1.00
# 2014-01-01 01:00:00   NaN  217.4  13.39     15.05      0.71
# 2014-01-01 01:10:00   NaN  215.6  13.23     15.62      0.88
# 2014-01-01 01:20:00   NaN  211.6  13.69     14.93      0.55
# 2014-01-01 01:30:00   NaN  212.6  13.68     15.74      0.89
# 2014-01-01 01:40:00   NaN  213.8  14.56     16.72      0.80
# 2014-01-01 01:50:00   NaN  210.9  15.08     17.14      0.80
# 2014-01-01 02:00:00   NaN  210.9  15.81     17.99      0.81
# 2014-01-01 00:00:00   7.4    NaN    NaN       NaN       NaN
# 2014-01-01 01:00:00   7.4    NaN    NaN       NaN       NaN
# 2014-01-01 02:00:00   7.4    NaN    NaN       NaN       NaN

# %% [markdown]
# ![](imgs/merging_concat_basic.png)

# %%
new = pd.concat([wind, model], axis = 1, join = 'inner')

# %%
new.head(5)
# Out:
#                      wspd  wspd_max   wdir  wspd_std  M(m/s)  D(deg)  T(C)  \
# Timestamp
# 2013-09-04 00:00:00  2.21      2.58  113.5      0.11     3.8     118  17.3
# 2013-09-04 01:00:00  2.66      2.96  114.4      0.12     3.9     112  17.1
# 2013-09-04 02:00:00  4.70      5.00  120.8      0.12     4.0     114  17.0
# 2013-09-04 03:00:00  4.72      5.17  124.5      0.16     4.2     116  17.0
# 2013-09-04 04:00:00  3.50      3.85  123.3      0.15     4.2     120  16.9
#
#                      De(k/m3)  PRE(hPa)  RiNumber  RH(%)
# Timestamp
# 2013-09-04 00:00:00      1.22    1013.4      1.87   91.0
# 2013-09-04 01:00:00      1.22    1013.2      1.03   94.4
# 2013-09-04 02:00:00      1.22    1012.9      0.65   96.1
# 2013-09-04 03:00:00      1.22    1012.7      0.55   95.8
# 2013-09-04 04:00:00      1.22    1012.4      0.53   95.0

# %%
new.loc['2014/01/01 00:00':'2014/01/01 02:00']
# Out:
#                       wspd  wspd_max   wdir  wspd_std  M(m/s)  D(deg)  T(C)  \
# Timestamp
# 2014-01-01 00:00:00  12.15     13.95  224.6      0.60    12.7     206   7.4
# 2014-01-01 01:00:00  13.39     15.05  217.4      0.71    12.7     206   7.4
# 2014-01-01 02:00:00  15.81     17.99  210.9      0.81    13.1     202   7.4
#
#                      De(k/m3)  PRE(hPa)  RiNumber  RH(%)
# Timestamp
# 2014-01-01 00:00:00      1.23     992.4      0.03   90.9
# 2014-01-01 01:00:00      1.23     992.4      0.03   89.2
# 2014-01-01 02:00:00      1.23     992.3      0.02   87.8

# %% [markdown]
# `concat` permite 'unir' estructuras de datos pandas usando filas o columnas.
#
# Y lo anterior no os ha quedado nada claro!!! Y no habéis preguntado!!!
#
# Veamos un ejemplo más simple:

# %%
np.random.seed(123)
df1 = pd.DataFrame(np.random.randn(10,2), 
                   columns = ['A', 'B'], 
                   index = np.arange(10))
df2 = pd.DataFrame(np.random.randn(4,3), 
                   columns = ['A', 'B', 'C'], 
                   index = np.arange(8, 12))

# %%
df1
# Out:
#           A         B
# 0 -1.085631  0.997345
# 1  0.282978 -1.506295
# 2 -0.578600  1.651437
# 3 -2.426679 -0.428913
# 4  1.265936 -0.866740
# 5 -0.678886 -0.094709
# 6  1.491390 -0.638902
# 7 -0.443982 -0.434351
# 8  2.205930  2.186786
# 9  1.004054  0.386186

# %%
df2
# Out:
#            A         B         C
# 8   0.737369  1.490732 -0.935834
# 9   1.175829 -1.253881 -0.637752
# 10  0.907105 -1.428681 -0.140069
# 11 -0.861755 -0.255619 -2.798589

# %%
new = pd.concat([df1, df2], axis = 0, join = 'inner')
new
# Out:
#            A         B
# 0  -1.085631  0.997345
# 1   0.282978 -1.506295
# 2  -0.578600  1.651437
# 3  -2.426679 -0.428913
# 4   1.265936 -0.866740
# 5  -0.678886 -0.094709
# 6   1.491390 -0.638902
# 7  -0.443982 -0.434351
# 8   2.205930  2.186786
# 9   1.004054  0.386186
# 8   0.737369  1.490732
# 9   1.175829 -1.253881
# 10  0.907105 -1.428681
# 11 -0.861755 -0.255619

# %%
new = pd.concat([df1, df2], axis = 1, join = 'inner')
new
# Out:
#           A         B         A         B         C
# 8  2.205930  2.186786  0.737369  1.490732 -0.935834
# 9  1.004054  0.386186  1.175829 -1.253881 -0.637752

# %% [markdown]
# Normalmente uso esta última opción con nombres de columnas diferentes porque normalmente es lo que quiero hacer...

# %% [markdown]
# ## Concatenando usando el método `append`
#
# Podemos hacer algo parecido a lo anterior usando el método `append` de las estructuras de datos:

# %%
wind.append(model)
# Out:
#                      D(deg)  De(k/m3)  M(m/s)  PRE(hPa)  RH(%)  RiNumber  \
# Timestamp
# 2013-09-04 00:00:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 00:10:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 00:20:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 00:30:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 00:40:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 00:50:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 01:00:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 01:10:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 01:20:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 01:30:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 01:40:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 01:50:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 02:00:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 02:10:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 02:20:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 02:30:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 02:40:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 02:50:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 03:00:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 03:10:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 03:20:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 03:30:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 03:40:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 03:50:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 04:00:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 04:10:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 04:20:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 04:30:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 04:40:00     NaN       NaN     NaN       NaN    NaN       NaN
# 2013-09-04 04:50:00     NaN       NaN     NaN       NaN    NaN       NaN
# ...                     ...       ...     ...       ...    ...       ...
# 2015-09-09 18:00:00      78      1.22     9.3    1010.4   67.1     -0.11
# 2015-09-09 19:00:00      79      1.22     9.4    1010.3   66.7      0.02
# 2015-09-09 20:00:00      79      1.22     9.3    1010.4   66.9      0.01
# 2015-09-09 21:00:00      81      1.22     9.3    1010.5   68.0      0.10
# 2015-09-09 22:00:00      83      1.22     9.5    1010.6   71.9     -0.10
# 2015-09-09 23:00:00      85      1.22     9.4    1010.6   72.9     -0.27
# 2015-09-10 00:00:00      87      1.22     9.5    1010.7   74.0     -0.95
# 2015-09-10 01:00:00      90      1.22     9.4    1010.7   74.3     -1.43
# 2015-09-10 02:00:00      93      1.22     9.4    1010.7   74.5     -1.86
# 2015-09-10 03:00:00      96      1.22     9.4    1010.7   74.6     -2.17
# 2015-09-10 04:00:00      96      1.22     9.4    1010.6   75.4     -2.23
# 2015-09-10 05:00:00      96      1.22     9.4    1010.6   76.0     -2.37
# 2015-09-10 06:00:00      96      1.23     9.4    1010.6   76.4     -2.41
# 2015-09-10 07:00:00      95      1.23     9.5    1010.5   76.9     -2.34
# 2015-09-10 08:00:00      94      1.23     9.3    1010.5   77.5     -2.82
# 2015-09-10 09:00:00      92      1.23     9.0    1010.6   77.6     -3.12
# 2015-09-10 10:00:00      89      1.22     8.7    1010.6   77.0     -2.62
# 2015-09-10 11:00:00      86      1.22     8.7    1010.6   75.5     -1.92
# 2015-09-10 12:00:00      83      1.22     8.8    1010.6   73.7     -1.22
# 2015-09-10 13:00:00      83      1.22     9.0    1010.3   71.8     -0.71
# 2015-09-10 14:00:00      84      1.22     9.3    1009.9   69.4     -0.32
# 2015-09-10 15:00:00      85      1.22     9.5    1009.6   66.5     -0.03
# 2015-09-10 16:00:00      85      1.22     9.4    1009.3   65.9      0.05
# 2015-09-10 17:00:00      85      1.22     9.4    1009.0   66.3      0.14
# 2015-09-10 18:00:00      85      1.22     9.2    1008.7   67.6      0.20
# 2015-09-10 19:00:00      85      1.22     9.2    1008.5   67.9      0.25
# 2015-09-10 20:00:00      85      1.21     9.2    1008.3   68.0      0.28
# 2015-09-10 21:00:00      87      1.21     9.5    1008.1   69.1      0.24
# 2015-09-10 22:00:00      90      1.21    10.0    1008.0   72.3      0.10
# 2015-09-10 23:00:00      94      1.22    10.0    1007.9   73.9     -0.06
#
#                      T(C)   wdir  wspd  wspd_max  wspd_std
# Timestamp
# 2013-09-04 00:00:00   NaN  113.5  2.21      2.58      0.11
# 2013-09-04 00:10:00   NaN   99.9  1.69      2.31      0.35
# 2013-09-04 00:20:00   NaN   96.0  1.28      1.50      0.08
# 2013-09-04 00:30:00   NaN   99.2  1.94      2.39      0.26
# 2013-09-04 00:40:00   NaN  108.4  2.17      2.67      0.23
# 2013-09-04 00:50:00   NaN  105.0  2.25      2.89      0.35
# 2013-09-04 01:00:00   NaN  114.4  2.66      2.96      0.12
# 2013-09-04 01:10:00   NaN  119.1  3.55      4.33      0.46
# 2013-09-04 01:20:00   NaN  122.1  4.26      4.50      0.08
# 2013-09-04 01:30:00   NaN  120.8  4.62      5.10      0.23
# 2013-09-04 01:40:00   NaN  124.8  5.30      5.63      0.16
# 2013-09-04 01:50:00   NaN  120.8  4.68      5.17      0.17
# 2013-09-04 02:00:00   NaN  120.8  4.70      5.00      0.12
# 2013-09-04 02:10:00   NaN  121.0  4.87      5.22      0.14
# 2013-09-04 02:20:00   NaN  128.1  5.14      5.72      0.35
# 2013-09-04 02:30:00   NaN  127.2  5.54      5.99      0.22
# 2013-09-04 02:40:00   NaN  128.0  5.41      5.75      0.17
# 2013-09-04 02:50:00   NaN  127.9  5.16      5.56      0.12
# 2013-09-04 03:00:00   NaN  124.5  4.72      5.17      0.16
# 2013-09-04 03:10:00   NaN  125.5  4.56      4.81      0.08
# 2013-09-04 03:20:00   NaN  126.4  4.32      4.57      0.10
# 2013-09-04 03:30:00   NaN  128.8  4.25      4.59      0.21
# 2013-09-04 03:40:00   NaN  123.4  3.84      4.09      0.08
# 2013-09-04 03:50:00   NaN  126.7  3.95      4.26      0.13
# 2013-09-04 04:00:00   NaN  123.3  3.50      3.85      0.15
# 2013-09-04 04:10:00   NaN  122.7  3.36      3.63      0.11
# 2013-09-04 04:20:00   NaN  132.3  3.80      3.99      0.10
# 2013-09-04 04:30:00   NaN  135.8  4.12      4.47      0.15
# 2013-09-04 04:40:00   NaN  131.1  4.25      4.69      0.17
# 2013-09-04 04:50:00   NaN  132.6  4.03      4.62      0.20
# ...                   ...    ...   ...       ...       ...
# 2015-09-09 18:00:00  15.7    NaN   NaN       NaN       NaN
# 2015-09-09 19:00:00  15.8    NaN   NaN       NaN       NaN
# 2015-09-09 20:00:00  15.9    NaN   NaN       NaN       NaN
# 2015-09-09 21:00:00  15.9    NaN   NaN       NaN       NaN
# 2015-09-09 22:00:00  15.7    NaN   NaN       NaN       NaN
# 2015-09-09 23:00:00  15.5    NaN   NaN       NaN       NaN
# 2015-09-10 00:00:00  15.3    NaN   NaN       NaN       NaN
# 2015-09-10 01:00:00  15.1    NaN   NaN       NaN       NaN
# 2015-09-10 02:00:00  14.8    NaN   NaN       NaN       NaN
# 2015-09-10 03:00:00  14.6    NaN   NaN       NaN       NaN
# 2015-09-10 04:00:00  14.5    NaN   NaN       NaN       NaN
# 2015-09-10 05:00:00  14.4    NaN   NaN       NaN       NaN
# 2015-09-10 06:00:00  14.4    NaN   NaN       NaN       NaN
# 2015-09-10 07:00:00  14.3    NaN   NaN       NaN       NaN
# 2015-09-10 08:00:00  14.2    NaN   NaN       NaN       NaN
# 2015-09-10 09:00:00  14.2    NaN   NaN       NaN       NaN
# 2015-09-10 10:00:00  14.4    NaN   NaN       NaN       NaN
# 2015-09-10 11:00:00  14.7    NaN   NaN       NaN       NaN
# 2015-09-10 12:00:00  15.0    NaN   NaN       NaN       NaN
# 2015-09-10 13:00:00  15.3    NaN   NaN       NaN       NaN
# 2015-09-10 14:00:00  15.6    NaN   NaN       NaN       NaN
# 2015-09-10 15:00:00  15.9    NaN   NaN       NaN       NaN
# 2015-09-10 16:00:00  16.0    NaN   NaN       NaN       NaN
# 2015-09-10 17:00:00  16.0    NaN   NaN       NaN       NaN
# 2015-09-10 18:00:00  16.1    NaN   NaN       NaN       NaN
# 2015-09-10 19:00:00  16.1    NaN   NaN       NaN       NaN
# 2015-09-10 20:00:00  16.2    NaN   NaN       NaN       NaN
# 2015-09-10 21:00:00  16.2    NaN   NaN       NaN       NaN
# 2015-09-10 22:00:00  16.0    NaN   NaN       NaN       NaN
# 2015-09-10 23:00:00  15.8    NaN   NaN       NaN       NaN
#
# [378686 rows x 11 columns]

# %% [markdown]
# Normalmente esto no es lo que quiero hacer. Normalmente quiero juntar con cierta lógica estructuras de datos pandas y para ello podemos usar `pd.merge`...
#
# ## Usando `pd.merge` como en una base de datos SQL

# %%
pd.merge(wind, model, left_index = True, right_index = True, how = 'inner').head(5)
# Out:
#                      wspd  wspd_max   wdir  wspd_std  M(m/s)  D(deg)  T(C)  \
# Timestamp
# 2013-09-04 00:00:00  2.21      2.58  113.5      0.11     3.8     118  17.3
# 2013-09-04 01:00:00  2.66      2.96  114.4      0.12     3.9     112  17.1
# 2013-09-04 02:00:00  4.70      5.00  120.8      0.12     4.0     114  17.0
# 2013-09-04 03:00:00  4.72      5.17  124.5      0.16     4.2     116  17.0
# 2013-09-04 04:00:00  3.50      3.85  123.3      0.15     4.2     120  16.9
#
#                      De(k/m3)  PRE(hPa)  RiNumber  RH(%)
# Timestamp
# 2013-09-04 00:00:00      1.22    1013.4      1.87   91.0
# 2013-09-04 01:00:00      1.22    1013.2      1.03   94.4
# 2013-09-04 02:00:00      1.22    1012.9      0.65   96.1
# 2013-09-04 03:00:00      1.22    1012.7      0.55   95.8
# 2013-09-04 04:00:00      1.22    1012.4      0.53   95.0

# %%
(pd.merge(wind, model, left_index = True, right_index = True, how = 'inner') == 
 pd.concat([wind, model], axis = 1, join = 'inner')).all().all()
# Out:
# True

# %% [markdown]
# Imaginemos que queremos unir dos `DataFrame`s usando valores de columnas:

# %%
df1 = pd.DataFrame(
    np.array([
        np.arange(1, 11),
        np.random.choice([1,2,3], size = 10),
        np.arange(1, 11) * 10
    ]).T,
    columns = ['A', 'col', 'B']
)
df2 = pd.DataFrame(
    np.array([
        np.arange(11, 21),
        np.random.choice([1,2,3], size = 10),
        np.arange(1, 11) * 100
    ]).T,
    columns = ['A', 'col', 'B']
)
display(df1)
display(df2)
# Out:
#     A  col    B
# 0   1    3   10
# 1   2    3   20
# 2   3    1   30
# 3   4    1   40
# 4   5    2   50
# 5   6    3   60
# 6   7    3   70
# 7   8    3   80
# 8   9    1   90
# 9  10    1  100
#     A  col     B
# 0  11    1   100
# 1  12    3   200
# 2  13    2   300
# 3  14    3   400
# 4  15    3   500
# 5  16    3   600
# 6  17    3   700
# 7  18    1   800
# 8  19    3   900
# 9  20    1  1000

# %%
pd.merge(df1, df2, on = ['col'])
# Out:
#     A_x  col  B_x  A_y   B_y
# 0     1    3   10   12   200
# 1     1    3   10   14   400
# 2     1    3   10   15   500
# 3     1    3   10   16   600
# 4     1    3   10   17   700
# 5     1    3   10   19   900
# 6     2    3   20   12   200
# 7     2    3   20   14   400
# 8     2    3   20   15   500
# 9     2    3   20   16   600
# 10    2    3   20   17   700
# 11    2    3   20   19   900
# 12    6    3   60   12   200
# 13    6    3   60   14   400
# 14    6    3   60   15   500
# 15    6    3   60   16   600
# 16    6    3   60   17   700
# 17    6    3   60   19   900
# 18    7    3   70   12   200
# 19    7    3   70   14   400
# 20    7    3   70   15   500
# 21    7    3   70   16   600
# 22    7    3   70   17   700
# 23    7    3   70   19   900
# 24    8    3   80   12   200
# 25    8    3   80   14   400
# 26    8    3   80   15   500
# 27    8    3   80   16   600
# 28    8    3   80   17   700
# 29    8    3   80   19   900
# 30    3    1   30   11   100
# 31    3    1   30   18   800
# 32    3    1   30   20  1000
# 33    4    1   40   11   100
# 34    4    1   40   18   800
# 35    4    1   40   20  1000
# 36    9    1   90   11   100
# 37    9    1   90   18   800
# 38    9    1   90   20  1000
# 39   10    1  100   11   100
# 40   10    1  100   18   800
# 41   10    1  100   20  1000
# 42    5    2   50   13   300

# %%
# Jugad un poco y mirad las keywords del pd.merge para ver otras opciones

# %% [markdown]
# ## Combinando usando el método `join`

# %% [markdown]
# Un poco más de lo mismo. El método `join` nos ayuda, nuevamente, a unir estructuras de datos pandas. Vamos a ver unos pocos ejemplos rápidos:

# %%
wind.join(model, how = 'left').head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-8bfb4a280e1f> in <module>()
# ----> 1 wind.join(model, how = 'left').head(10)
#
# d:\users\X003621\AppData\Local\Continuum\Miniconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4017         # For SparseDataFrame's benefit
#    4018         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4019                                  rsuffix=rsuffix, sort=sort)
#    4020
#    4021     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# d:\users\X003621\AppData\Local\Continuum\Miniconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4031             return merge(self, other, left_on=on, how=how,
#    4032                          left_index=on is None, right_index=True,
# -> 4033                          suffixes=(lsuffix, rsuffix), sort=sort)
#    4034         else:
#    4035             if on is not None:
#
# d:\users\X003621\AppData\Local\Continuum\Miniconda3\lib\site-packages\pandas\tools\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy)
#      36                          right_index=right_index, sort=sort, suffixes=suffixes,
#      37                          copy=copy)
# ---> 38     return op.get_result()
#      39 if __debug__:
#      40     merge.__doc__ = _merge_doc % '\nleft : DataFrame'
#
# d:\users\X003621\AppData\Local\Continuum\Miniconda3\lib\site-packages\pandas\tools\merge.py in get_result(self)
#     190
#     191         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 192                                                      rdata.items, rsuf)
#     193
#     194         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# d:\users\X003621\AppData\Local\Continuum\Miniconda3\lib\site-packages\pandas\core\internals.py in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    3969         if not lsuffix and not rsuffix:
#    3970             raise ValueError('columns overlap but no suffix specified: %s' %
# -> 3971                              to_rename)
#    3972
#    3973         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index(['col'], dtype='object')

# %%
wind.head()
# Out:
#                      wspd  wspd_max   wdir  wspd_std  col
# Timestamp
# 2013-09-04 00:00:00  2.21      2.58  113.5      0.11    2
# 2013-09-04 00:10:00  1.69      2.31   99.9      0.35    3
# 2013-09-04 00:20:00  1.28      1.50   96.0      0.08    1
# 2013-09-04 00:30:00  1.94      2.39   99.2      0.26    2
# 2013-09-04 00:40:00  2.17      2.67  108.4      0.23    1
